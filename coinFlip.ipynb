# %%
import IPython

# %%
def in_colab():
    try:
        import google.colab
        return True
    except:
        return False

SolutionToTask2 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1Pt0yZptC1NZCAxL_vD2Xza6Av6IFjPF0#scrollTo=H96SMjBvxIZI' if in_colab() else 'Coin_Flip_Experiment_Exercises_Solutions.ipynb#task2')))
SolutionToTask3 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1Pt0yZptC1NZCAxL_vD2Xza6Av6IFjPF0#scrollTo=QybWUMGROEan' if in_colab() else 'Coin_Flip_Experiment_Exercises_Solutions.ipynb#task3')))
SolutionToTask4 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1Pt0yZptC1NZCAxL_vD2Xza6Av6IFjPF0#scrollTo=clxQVSv6OEan' if in_colab() else 'Coin_Flip_Experiment_Exercises_Solutions.ipynb#task4')))

# %%
#
# you may use method 'randrange' for this task
# randrange(n) returns a value from {0,1,...,n-1} randomly
#

#
from random import randrange

for experiment in [100,1000,10000,100000]:
    heads = tails = 0
    for i in range(experiment):
        if randrange(100) <60: heads = heads + 1  # probabilty close to ideal 0.6
        else: tails = tails + 1   # probability close to ideal 0.4
    print("experiment:",experiment)
    print("heads =",heads,"  tails = ",tails)
    print("the ratio of #heads/#tails is",(round(heads/tails,4)))
    print()
#
# Out:
# experiment: 100
# heads = 65   tails =  35
# the ratio of #heads/#tails is 1.8571
#
# experiment: 1000
# heads = 583   tails =  417
# the ratio of #heads/#tails is 1.3981
#
# experiment: 10000
# heads = 6033   tails =  3967
# the ratio of #heads/#tails is 1.5208
#
# experiment: 100000
# heads = 60207   tails =  39793
# the ratio of #heads/#tails is 1.513

# %%
def biased_coin(N,B):
    from random import randrange
    random_number = randrange(N)
    if random_number < B:
        return "Heads"
    else:
        return "Tails"
    
print(f"Experiment: {experiment}")
print(f"Heads = {heads}  Tails = {tails}")
ratio = round(heads / tails, 4) if tails != 0 else "Infinity"
print(f"Ratio (#Heads / #Tails) = {ratio}\n")
# Out:
# Experiment: 100000
# Heads = 60207  Tails = 39793
# Ratio (#Heads / #Tails) = 1.513

# %%
N = 101
B = randrange(N+1)

total_tosses = 500
the_number_of_heads = 0
for i in range(total_tosses):
    if biased_coin(N,B) == "Heads":
        the_number_of_heads = the_number_of_heads + 1

my_guess =  the_number_of_heads/total_tosses
real_bias = B/N
error = abs(my_guess-real_bias)/real_bias*100

print("my guess is",my_guess)
print("real bias is",real_bias)
print("error (%) is",error)
# Out:
# my guess is 0.8
# real bias is 0.801980198019802
# error (%) is 0.2469135802469138
